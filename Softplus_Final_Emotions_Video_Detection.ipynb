# %% [markdown]
# # Emotion Detection Training
# This project is inspired from https://github.com/dhruvpandey662/Emotion-detection
#
# We will be training using softplus activation function.
#
# Data Source: https://www.kaggle.com/datasets/ananthu017/emotion-detection-fer
#
# Note: Unzip the file `data.zip` and move both folders `train` and `test` to the root directory

# %% [markdown]
# ## Import Statements

# %%
# If you do not have those libraries:
# !pip install tensorflow
# !pip install keras

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.layers import Flatten, Dense
from keras.models import Model
from tensorflow.keras.utils import img_to_array, load_img
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.mobilenet import MobileNet, preprocess_input
from keras.losses import categorical_crossentropy

# %% [markdown]
# ## Build the model
# We will be using MobileNet as it good base to start with. MobileNet has 28 layers of CNN and non-CNN layers

# %%
#The input_shape parameter is set to (224, 224, 3), which represents the expected input image shape with height, width, and 3 color channels (RGB).
#The include_top parameter is set to False, which means the last fully connected layer (top) of the MobileNet model will not be included.
base_model = MobileNet( input_shape=(224,224,3), include_top= False )

#By setting trainable to False, we are essentially freezing the weights of the pre-trained model's layers, which means they will not be updated during training.
for layer in base_model.layers:
  layer.trainable = False

# Set the output tensor to a 1 dimensional vector
x = Flatten()(base_model.output)
# Adds dense layer of 7 units. Softmax for common classifications problems
x = Dense(units=7 , activation='sigmoid' )(x)

# creating our model.
model = Model(base_model.input, x)

# %%
model.compile(optimizer='adam', loss= categorical_crossentropy , metrics=['accuracy']  )

# %% [markdown]
# ## Preparing Data Using Data Generator

# %%
# creating an object as an instance of "ImageDatagenerator"
train_datagen = ImageDataGenerator(
     zoom_range = 0.2,
     shear_range = 0.2,
     horizontal_flip=True,
     rescale = 1./255
)

# set the image to 224 x 224 and train by batch of 32
train_data = train_datagen.flow_from_directory(directory= "./train",
                                               target_size=(224,224),
                                               batch_size=32,
                                  )


train_data.class_indices

# %%
### Test data
val_datagen = ImageDataGenerator(rescale = 1./255 )

val_data = val_datagen.flow_from_directory(directory= "./test",
                                           target_size=(224,224),
                                           batch_size=32,
                                  )

# %% [markdown]
# ## Early stopping and model checkpoint
# This is to prevent the model from being overtrain

# %%
# We will save the weights of the epoch on the modelCheckpoint and use the min delta to stop at the optimal epochs to prevent overtraining
from keras.callbacks import ModelCheckpoint, EarlyStopping


# early stopping
es = EarlyStopping(monitor='val_accuracy', min_delta= 0.01 , patience= 5, verbose= 1, mode='auto')
# model check point
mc = ModelCheckpoint(filepath="softplus1.h5", monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode = 'auto')

# puting call back in a list
call_back = [es, mc]

# %%
hist = model.fit(train_data,
                           steps_per_epoch= 30,
                           epochs= 30,
                           validation_data= val_data,
                           validation_steps= 8,
                           callbacks=[es,mc])
# Out:
# Epoch 1/30
# 60/60 [==============================] - ETA: 0s - loss: 7.4508 - accuracy: 0.3339
# Epoch 1: val_accuracy improved from -inf to 0.31250, saving model to sigmoid4.h5
# 60/60 [==============================] - 45s 721ms/step - loss: 7.4508 - accuracy: 0.3339 - val_loss: 7.8471 - val_accuracy: 0.3125
# Epoch 2/30
# 60/60 [==============================] - ETA: 0s - loss: 5.7476 - accuracy: 0.4031
# Epoch 2: val_accuracy improved from 0.31250 to 0.44141, saving model to sigmoid4.h5
# 60/60 [==============================] - 42s 702ms/step - loss: 5.7476 - accuracy: 0.4031 - val_loss: 5.5479 - val_accuracy: 0.4414
# Epoch 3/30
# 60/60 [==============================] - ETA: 0s - loss: 5.3848 - accuracy: 0.4635
# Epoch 3: val_accuracy did not improve from 0.44141
# 60/60 [==============================] - 41s 689ms/step - loss: 5.3848 - accuracy: 0.4635 - val_loss: 5.7470 - val_accuracy: 0.4414
# Epoch 4/30
# 60/60 [==============================] - ETA: 0s - loss: 7.0898 - accuracy: 0.4401
# Epoch 4: val_accuracy did not improve from 0.44141
# 60/60 [==============================] - 41s 683ms/step - loss: 7.0898 - accuracy: 0.4401 - val_loss: 6.0166 - val_accuracy: 0.3906
# Epoch 5/30
# 60/60 [==============================] - ETA: 0s - loss: 6.1819 - accuracy: 0.4766
# Epoch 5: val_accuracy improved from 0.44141 to 0.46484, saving model to sigmoid4.h5
# 60/60 [==============================] - 42s 690ms/step - loss: 6.1819 - accuracy: 0.4766 - val_loss: 6.3132 - val_accuracy: 0.4648
# Epoch 6/30
# 60/60 [==============================] - ETA: 0s - loss: 6.0111 - accuracy: 0.4745
# Epoch 6: val_accuracy did not improve from 0.46484
# 60/60 [==============================] - 41s 684ms/step - loss: 6.0111 - accuracy: 0.4745 - val_loss: 7.7826 - val_accuracy: 0.4492
# Epoch 7/30
# 60/60 [==============================] - ETA: 0s - loss: 6.4879 - accuracy: 0.4677
# Epoch 7: val_accuracy did not improve from 0.46484
# 60/60 [==============================] - 39s 651ms/step - loss: 6.4879 - accuracy: 0.4677 - val_loss: 7.1017 - val_accuracy: 0.4141
# Epoch 8/30
# 60/60 [==============================] - ETA: 0s - loss: 6.4467 - accuracy: 0.4740
# Epoch 8: val_accuracy did not improve from 0.46484
# 60/60 [==============================] - 39s 641ms/step - loss: 6.4467 - accuracy: 0.4740 - val_loss: 7.2300 - val_accuracy: 0.4375
# Epoch 9/30
# 60/60 [==============================] - ETA: 0s - loss: 6.8070 - accuracy: 0.4823
# Epoch 9: val_accuracy improved from 0.46484 to 0.48828, saving model to sigmoid4.h5
# 60/60 [==============================] - 38s 632ms/step - loss: 6.8070 - accuracy: 0.4823 - val_loss: 6.2325 - val_accuracy: 0.4883
# Epoch 10/30
# 60/60 [==============================] - ETA: 0s - loss: 6.7207 - accuracy: 0.4724
# Epoch 10: val_accuracy did not improve from 0.48828
# 60/60 [==============================] - 38s 624ms/step - loss: 6.7207 - accuracy: 0.4724 - val_loss: 5.5344 - val_accuracy: 0.4805
# Epoch 11/30
# 60/60 [==============================] - ETA: 0s - loss: 6.4500 - accuracy: 0.5057
# Epoch 11: val_accuracy did not improve from 0.48828
# 60/60 [==============================] - 38s 625ms/step - loss: 6.4500 - accuracy: 0.5057 - val_loss: 8.3819 - val_accuracy: 0.4883
# Epoch 12/30
# 60/60 [==============================] - ETA: 0s - loss: 6.6297 - accuracy: 0.5036
# Epoch 12: val_accuracy did not improve from 0.48828
# 60/60 [==============================] - 38s 625ms/step - loss: 6.6297 - accuracy: 0.5036 - val_loss: 9.5706 - val_accuracy: 0.4219
# Epoch 13/30
# 60/60 [==============================] - ETA: 0s - loss: 6.9538 - accuracy: 0.5129
# Epoch 13: val_accuracy improved from 0.48828 to 0.49609, saving model to sigmoid4.h5
# 60/60 [==============================] - 37s 615ms/step - loss: 6.9538 - accuracy: 0.5129 - val_loss: 6.7446 - val_accuracy: 0.4961
# Epoch 14/30
# 60/60 [==============================] - ETA: 0s - loss: 6.6045 - accuracy: 0.5130
# Epoch 14: val_accuracy improved from 0.49609 to 0.50391, saving model to sigmoid4.h5
# 60/60 [==============================] - 37s 612ms/step - loss: 6.6045 - accuracy: 0.5130 - val_loss: 7.0153 - val_accuracy: 0.5039
# Epoch 15/30
# 60/60 [==============================] - ETA: 0s - loss: 6.6118 - accuracy: 0.5161
# Epoch 15: val_accuracy improved from 0.50391 to 0.50781, saving model to sigmoid4.h5
# 60/60 [==============================] - 37s 621ms/step - loss: 6.6118 - accuracy: 0.5161 - val_loss: 7.3949 - val_accuracy: 0.5078
# Epoch 16/30
# 60/60 [==============================] - ETA: 0s - loss: 6.9242 - accuracy: 0.5224
# Epoch 16: val_accuracy did not improve from 0.50781
# 60/60 [==============================] - 38s 625ms/step - loss: 6.9242 - accuracy: 0.5224 - val_loss: 7.7107 - val_accuracy: 0.4766
# Epoch 17/30
# 60/60 [==============================] - ETA: 0s - loss: 6.6583 - accuracy: 0.5276
# Epoch 17: val_accuracy improved from 0.50781 to 0.51562, saving model to sigmoid4.h5
# 60/60 [==============================] - 36s 602ms/step - loss: 6.6583 - accuracy: 0.5276 - val_loss: 7.0846 - val_accuracy: 0.5156
# Epoch 18/30
# 60/60 [==============================] - ETA: 0s - loss: 7.2088 - accuracy: 0.5104
# Epoch 18: val_accuracy did not improve from 0.51562
# 60/60 [==============================] - 37s 617ms/step - loss: 7.2088 - accuracy: 0.5104 - val_loss: 8.4545 - val_accuracy: 0.4531
# Epoch 19/30
# 60/60 [==============================] - ETA: 0s - loss: 7.3016 - accuracy: 0.5135
# Epoch 19: val_accuracy improved from 0.51562 to 0.53125, saving model to sigmoid4.h5
# 60/60 [==============================] - 36s 604ms/step - loss: 7.3016 - accuracy: 0.5135 - val_loss: 6.7462 - val_accuracy: 0.5312
# Epoch 20/30
# 60/60 [==============================] - ETA: 0s - loss: 7.0063 - accuracy: 0.5365
# Epoch 20: val_accuracy did not improve from 0.53125
# 60/60 [==============================] - 36s 599ms/step - loss: 7.0063 - accuracy: 0.5365 - val_loss: 8.4756 - val_accuracy: 0.4688
# Epoch 21/30
# 60/60 [==============================] - ETA: 0s - loss: 6.8616 - accuracy: 0.5161
# Epoch 21: val_accuracy did not improve from 0.53125
# 60/60 [==============================] - 35s 584ms/step - loss: 6.8616 - accuracy: 0.5161 - val_loss: 7.6106 - val_accuracy: 0.5195
# Epoch 22/30
# 60/60 [==============================] - ETA: 0s - loss: 6.9228 - accuracy: 0.5489
# Epoch 22: val_accuracy did not improve from 0.53125
# 60/60 [==============================] - 34s 570ms/step - loss: 6.9228 - accuracy: 0.5489 - val_loss: 7.2251 - val_accuracy: 0.4844
# Epoch 23/30
# 60/60 [==============================] - ETA: 0s - loss: 7.7301 - accuracy: 0.5141
# Epoch 23: val_accuracy did not improve from 0.53125
# 60/60 [==============================] - 35s 573ms/step - loss: 7.7301 - accuracy: 0.5141 - val_loss: 8.0649 - val_accuracy: 0.5234
# Epoch 24/30
# 60/60 [==============================] - ETA: 0s - loss: 8.0925 - accuracy: 0.5328
# Epoch 24: val_accuracy improved from 0.53125 to 0.55078, saving model to sigmoid4.h5
# 60/60 [==============================] - 34s 570ms/step - loss: 8.0925 - accuracy: 0.5328 - val_loss: 7.5546 - val_accuracy: 0.5508
# Epoch 25/30
# 60/60 [==============================] - ETA: 0s - loss: 6.3514 - accuracy: 0.5802
# Epoch 25: val_accuracy did not improve from 0.55078
# 60/60 [==============================] - 34s 564ms/step - loss: 6.3514 - accuracy: 0.5802 - val_loss: 9.1043 - val_accuracy: 0.4766
# Epoch 26/30
# 60/60 [==============================] - ETA: 0s - loss: 7.5479 - accuracy: 0.5394
# Epoch 26: val_accuracy did not improve from 0.55078
# 60/60 [==============================] - 33s 549ms/step - loss: 7.5479 - accuracy: 0.5394 - val_loss: 8.5331 - val_accuracy: 0.5430
# Epoch 27/30
# 60/60 [==============================] - ETA: 0s - loss: 8.7530 - accuracy: 0.5339
# Epoch 27: val_accuracy improved from 0.55078 to 0.57422, saving model to sigmoid4.h5
# 60/60 [==============================] - 35s 582ms/step - loss: 8.7530 - accuracy: 0.5339 - val_loss: 7.5281 - val_accuracy: 0.5742
# Epoch 28/30
# 60/60 [==============================] - ETA: 0s - loss: 7.1270 - accuracy: 0.5484
# Epoch 28: val_accuracy did not improve from 0.57422
# 60/60 [==============================] - 38s 629ms/step - loss: 7.1270 - accuracy: 0.5484 - val_loss: 9.7599 - val_accuracy: 0.4453
# Epoch 29/30
# 60/60 [==============================] - ETA: 0s - loss: 6.6633 - accuracy: 0.5568
# Epoch 29: val_accuracy did not improve from 0.57422
# 60/60 [==============================] - 38s 631ms/step - loss: 6.6633 - accuracy: 0.5568 - val_loss: 9.0397 - val_accuracy: 0.4883
# Epoch 30/30
# 60/60 [==============================] - ETA: 0s - loss: 6.6563 - accuracy: 0.5578
# Epoch 30: val_accuracy did not improve from 0.57422
# 60/60 [==============================] - 35s 578ms/step - loss: 6.6563 - accuracy: 0.5578 - val_loss: 9.5639 - val_accuracy: 0.4648

# %%
# Loading the best fit model
from keras.models import load_model
model = load_model("./softplus1.h5")

# %%
h =  hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c = "red")
plt.title("loss vs v-loss")
plt.show()

# %%
# just to map o/p values
op = dict(zip( train_data.class_indices.values(), train_data.class_indices.keys()))

# %%
# path for the image to see if it predics correct class

path = "./test/fearful/im45.png"
img = load_img(path, target_size=(224,224) )

i = img_to_array(img)/255
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))

print(f" the image is of {op[pred]}")

# to display the image
plt.imshow(input_arr[0])
plt.title("input image")
plt.show()
# Out:
# 1/1 [==============================] - 0s 39ms/step
#  the image is of fearful
